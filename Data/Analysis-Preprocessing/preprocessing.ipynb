# %%
import pandas as pd
import numpy as np
import pycountry
import zipcodes
from geopy.geocoders import Nominatim
# Out:
# Collecting pycountry
#   Using cached pycountry-22.3.5.tar.gz (10.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: setuptools in c:\users\rafae\.conda\envs\infovis\lib\site-packages (from pycountry) (67.6.1)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml): started
#   Building wheel for pycountry (pyproject.toml): finished with status 'done'
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681896 sha256=0e54fa1d41891b25432b148e892ce9635842b99f318e7e21ccc2d41a78283c2e
#   Stored in directory: c:\users\rafae\appdata\local\pip\cache\wheels\cd\29\8b\617685ed7942656b36efb06ff9247dbe832e3f4f7724fffc09
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
# Read data
df_events = pd.read_csv('../Natural-Disasters.csv',delimiter=';')
df_location_data = pd.read_csv('../pend-gdis-1960-2018-disasterlocations.csv',delimiter=',')
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_38300\1686743832.py:2: DtypeWarning: Columns (18,19,24,25,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_events = pd.read_csv('../Natural-Disasters.csv',delimiter=';')

# %%
df_events
# Out:
#               Dis No  Year   Seq Glide Disaster Group Disaster Subgroup
# 0      1900-9002-CPV  1900  9002   NaN        Natural    Climatological  \
# 1      1900-9001-IND  1900  9001   NaN        Natural    Climatological
# 2      1902-0012-GTM  1902    12   NaN        Natural       Geophysical
# 3      1902-0003-GTM  1902     3   NaN        Natural       Geophysical
# 4      1902-0010-GTM  1902    10   NaN        Natural       Geophysical
# ...              ...   ...   ...   ...            ...               ...
# 16540  2023-0002-PHL  2023     2   NaN        Natural      Hydrological
# 16541  2023-0056-ZMB  2023    56   NaN        Natural      Hydrological
# 16542  2023-0046-NZL  2023    46   NaN        Natural      Hydrological
# 16543  2023-0032-USA  2023    32   NaN        Natural    Meteorological
# 16544  2023-0022-SRB  2023    22   NaN        Natural      Hydrological
#
#            Disaster Type  Disaster Subtype Disaster Subsubtype   Event Name
# 0                Drought           Drought                 NaN          NaN  \
# 1                Drought           Drought                 NaN          NaN
# 2             Earthquake   Ground movement                 NaN          NaN
# 3      Volcanic activity          Ash fall                 NaN  Santa Maria
# 4      Volcanic activity          Ash fall                 NaN  Santa Maria
# ...                  ...               ...                 ...          ...
# 16540              Flood               NaN                 NaN          NaN
# 16541              Flood               NaN                 NaN          NaN
# 16542              Flood               NaN                 NaN          NaN
# 16543              Storm  Convective storm             Tornado          NaN
# 16544              Flood    Riverine flood                 NaN          NaN
#
#        ... Reconstruction Costs, Adjusted ('000 US$)
# 0      ...                                       NaN  \
# 1      ...                                       NaN
# 2      ...                                       NaN
# 3      ...                                       NaN
# 4      ...                                       NaN
# ...    ...                                       ...
# 16540  ...                                       NaN
# 16541  ...                                       NaN
# 16542  ...                                       NaN
# 16543  ...                                       NaN
# 16544  ...                                       NaN
#
#       Insured Damages ('000 US$) Insured Damages, Adjusted ('000 US$)
# 0                            NaN                                  NaN  \
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
# ...                          ...                                  ...
# 16540                        NaN                                  NaN
# 16541                        NaN                                  NaN
# 16542                        NaN                                  NaN
# 16543                        NaN                                  NaN
# 16544                        NaN                                  NaN
#
#       Total Damages ('000 US$) Total Damages, Adjusted ('000 US$)
# 0                          NaN                                NaN  \
# 1                          NaN                                NaN
# 2                      25000.0                           843726.0
# 3                          NaN                                NaN
# 4                          NaN                                NaN
# ...                        ...                                ...
# 16540                  12000.0                                NaN
# 16541                      NaN                                NaN
# 16542                      NaN                                NaN
# 16543                      NaN                                NaN
# 16544                      NaN                                NaN
#
#                CPI Adm Level
# 0      2,849084409       NaN  \
# 1      2,849084409       NaN
# 2      2,963047785       NaN
# 3      2,963047785       NaN
# 4      2,963047785       NaN
# ...            ...       ...
# 16540          NaN       1;2
# 16541          NaN         2
# 16542          NaN         1
# 16543          NaN         1
# 16544          NaN       NaN
#
#                                             Admin1 Code        Admin2 Code
# 0                                                   NaN                NaN  \
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN                NaN
# ...                                                 ...                ...
# 16540  2357;2361;2362;2364;2368;67159;67162;67165;67166  24267;24272;67174
# 16541                                               NaN  65228;65231;65236
# 16542                                              2171                NaN
# 16543                                         3214;3224                NaN
# 16544                                               NaN                NaN
#
#                                            Geo Locations
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16540  Region II (Cagayan Valley), Region III (Centra...
# 16541                     Choma, Kalomo, Namwala (Adm2).
# 16542                                   Auckland (Adm1).
# 16543                           Alabama, Georgia (Adm1).
# 16544                                                NaN
#
# [16545 rows x 50 columns]

# %%
# Drop all events from before 1960
df_events = df_events[df_events["Year"] >= 1960]

# %%
# Drop disasters with certain subgroups that aren't relevant to the scope
df_events = df_events[df_events["Disaster Subgroup"] != "Biological"]
df_events = df_events[df_events["Disaster Subgroup"] != "Extra-terrestrial"]

# %%
# Returns ISO-3 code for a given country name
def get_country_code(c_name):
    country = pycountry.countries.get(name=c_name)
    code = None
    if country is not None:
        code = country.alpha_3
    return code

# %%
# Fill in missing ISO3 codes
df_location_data.loc[df_location_data["iso3"].isna(), "iso3"] = df_location_data[df_location_data["iso3"].isna()].apply(lambda x: get_country_code(x["country"]),axis=1)

# %%
# Fill in missing ISO3 codes not included in the Pycountry library
df_location_data.loc[df_location_data["country"] == "Palestina", "iso3"] = "PSE"
df_location_data.loc[df_location_data["country"] == "Virgin Islands; U.S.", "iso3"] = "VIR"
df_location_data.loc[df_location_data["country"] == "Reunion", "iso3"] = "REU"
df_location_data.loc[df_location_data["country"] == "Saint Helena", "iso3"] = "SHN"
df_location_data.loc[df_location_data["country"] == "Micronesia", "iso3"] = "FSM"
df_location_data.loc[df_location_data["country"] == "British Virgin Islands", "iso3"] = "VGB"

# %%
# Edit disasterno to be the same as in df_events
df_location_data["disasterno"] = df_location_data["disasterno"] + "-" + df_location_data["iso3"]

# %%
def extract_lat_long(row, key):
    location_data = df_location_data[df_location_data["disasterno"] == row["Dis No"]]
    if not location_data.empty:
        return location_data.iloc[0, :][key]
    else:
        return None

# %%
# Augment Latitude info
df_events["Latitude"] = df_events.apply(lambda row: extract_lat_long(row, "latitude"), axis=1)

# Augment Longitude info
df_events["Longitude"] = df_events.apply(lambda row: extract_lat_long(row, "longitude"), axis=1)

# %%
# Extract trajectory of disaster
def extract_trajectory(row):
    location_data = df_location_data[df_location_data["disasterno"] == row["Dis No"]]
    trajectory = []
    if not location_data.empty:
        for _, row in location_data.iterrows():
            trajectory.append((row["latitude"], row["longitude"]))
        return trajectory
    else:
        return None

# %%
# Augment trajectory info
df_events["Trajectory"] = df_events.apply(lambda row: extract_trajectory(row), axis=1)

# %%
df_events = df_events.drop(["Year", "Seq", "Glide", "Disaster Group", "Location", "OFDA Response", "Appeal", "Declaration", "Adm Level", "Admin1 Code", "Admin2 Code", "Geo Locations"], axis=1)

# %%
df_events
# Out:
#               Dis No Disaster Subgroup Disaster Type  Disaster Subtype
# 303    1960-0013-CHL       Geophysical    Earthquake           Tsunami  \
# 304    1960-0026-AIA    Meteorological         Storm  Tropical cyclone
# 305    1960-0025-ANT    Meteorological         Storm  Tropical cyclone
# 306    1960-0024-ATG    Meteorological         Storm  Tropical cyclone
# 307    1960-0030-BGD    Meteorological         Storm  Tropical cyclone
# ...              ...               ...           ...               ...
# 16540  2023-0002-PHL      Hydrological         Flood               NaN
# 16541  2023-0056-ZMB      Hydrological         Flood               NaN
# 16542  2023-0046-NZL      Hydrological         Flood               NaN
# 16543  2023-0032-USA    Meteorological         Storm  Convective storm
# 16544  2023-0022-SRB      Hydrological         Flood    Riverine flood
#
#       Disaster Subsubtype Event Name                         Country  ISO
# 303                   NaN        NaN                           Chile  CHL  \
# 304                   NaN      Donna                        Anguilla  AIA
# 305                   NaN      Donna            Netherlands Antilles  ANT
# 306                   NaN      Donna             Antigua and Barbuda  ATG
# 307                   NaN        NaN                      Bangladesh  BGD
# ...                   ...        ...                             ...  ...
# 16540                 NaN        NaN               Philippines (the)  PHL
# 16541                 NaN        NaN                          Zambia  ZMB
# 16542                 NaN        NaN                     New Zealand  NZL
# 16543             Tornado        NaN  United States of America (the)  USA
# 16544                 NaN        NaN                          Serbia  SRB
#
#                           Region Continent  ... No Homeless Total Affected
# 303                South America  Americas  ...         NaN      2003000.0  \
# 304                    Caribbean  Americas  ...      1000.0         1250.0
# 305                    Caribbean  Americas  ...         NaN            NaN
# 306                    Caribbean  Americas  ...         NaN            NaN
# 307                Southern Asia      Asia  ...         NaN            NaN
# ...                          ...       ...  ...         ...            ...
# 16540         South-Eastern Asia      Asia  ...         NaN      2000011.0
# 16541             Eastern Africa    Africa  ...         NaN        22000.0
# 16542  Australia and New Zealand   Oceania  ...      1614.0         5400.0
# 16543           Northern America  Americas  ...         NaN           49.0
# 16544            Southern Europe    Europe  ...         NaN          210.0
#
#       Reconstruction Costs ('000 US$)
# 303                               NaN  \
# 304                               NaN
# 305                               NaN
# 306                               NaN
# 307                               NaN
# ...                               ...
# 16540                             NaN
# 16541                             NaN
# 16542                             NaN
# 16543                             NaN
# 16544                             NaN
#
#        Reconstruction Costs, Adjusted ('000 US$)  Insured Damages ('000 US$)
# 303                                          NaN                         NaN  \
# 304                                          NaN                         NaN
# 305                                          NaN                         NaN
# 306                                          NaN                         NaN
# 307                                          NaN                         NaN
# ...                                          ...                         ...
# 16540                                        NaN                         NaN
# 16541                                        NaN                         NaN
# 16542                                        NaN                         NaN
# 16543                                        NaN                         NaN
# 16544                                        NaN                         NaN
#
#       Insured Damages, Adjusted ('000 US$)  Total Damages ('000 US$)
# 303                                    NaN                  550000.0  \
# 304                                    NaN                   35000.0
# 305                                    NaN                       NaN
# 306                                    NaN                       NaN
# 307                                    NaN                       NaN
# ...                                    ...                       ...
# 16540                                  NaN                   12000.0
# 16541                                  NaN                       NaN
# 16542                                  NaN                       NaN
# 16543                                  NaN                       NaN
# 16544                                  NaN                       NaN
#
#        Total Damages, Adjusted ('000 US$)          CPI
# 303                             5442439.0  10,10576299  \
# 304                              346337.0  10,10576299
# 305                                   NaN  10,10576299
# 306                                   NaN  10,10576299
# 307                                   NaN  10,10576299
# ...                                   ...          ...
# 16540                                 NaN          NaN
# 16541                                 NaN          NaN
# 16542                                 NaN          NaN
# 16543                                 NaN          NaN
# 16544                                 NaN          NaN
#
#                                               Trajectory
# 303    [(-41.47604118, -72.81041733), (-39.87852955, ...
# 304                                                 None
# 305                                                 None
# 306                                                 None
# 307                         [(22.69803384, 91.11882816)]
# ...                                                  ...
# 16540                                               None
# 16541                                               None
# 16542                                               None
# 16543                                               None
# 16544                                               None
#
# [14089 rows x 39 columns]

# %%
df_events.to_csv('../Preprocessed-Natural-Disasters.csv', sep=";", index=False)

# %%
df_events[df_events['Longitude'].isnull() & df_events['Latitude'].isnull()][['Country', 'Start Year']].head(15)
# Out:
#                   Country  Start Year
# 304              Anguilla        1960
# 305  Netherlands Antilles        1960
# 306   Antigua and Barbuda        1960
# 309            Bangladesh        1960
# 312             Hong Kong        1960
# 314            Bangladesh        1961
# 316            Bangladesh        1961
# 318                Canada        1961
# 320                France        1961
# 321                Greece        1961
# 322             Hong Kong        1961
# 324              Honduras        1961
# 325                 India        1961
# 326               Albania        1962
# 327                Canada        1962

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
    
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))

# %%
geolocator = Nominatim(user_agent='geoapiExercises')
def lat_long_to_state(lat,long):
    try:
        location = geolocator.reverse(f'{lat}, {long}')
    except:
        return None
    if (not location):
        return None
    address = location.raw['address']
    zip_code = address.get('postcode')
    state = address.get('state')
    if (state):
        return state
    if (not zip_code):
        return None
    
    if (len(zip_code) == 5 or len(zip_code) == 10):
        abrev = zipcodes.matching(f'{zip_code}')
        if (len(abrev) > 0):
            abrev = abrev[0]['state']
            return abbrev_to_us_state[abrev]
    return None

# %%
df_events['us state'] = df_events.apply(lambda row: lat_long_to_state(row['Latitude'],row['Longitude']), axis=1)
# Out:
# 10310
# 30403
# 30512
# 21011
# 80303
# 13022
# 28059
# 13022
# 13130
# 49500
# 72200
# 25167
# 34760
# 16450
# 50470
# 04390
# 16450
# 98822
# 34270
# 04390
# 11701
# 11701
# 60504
# 45502
# 37347
# 10310
# 98816
# 98811
# 33315
# 47748
# 48600
# 56600
# 33315
# 04390
# 16450
# 16450
# 48600
# 38300
# 22203
# 76873
# 76873
# 06023
# 25800
# 76873
# 78387
# 02100
# 33553
# 76873
# 34270
# 76873
# 76873
# 21012
# 60504
# 30512
# 70503
# 11701
# 30512
# 30508
# 70503
# 20097
# 55902
# 25167
# 04390
# 25167
# 28059
# 72300
# 76873
# 76873
# 06023
# 76873
# 97064
# 30403
# 33315
# 13130
# 07046
# 50102
# 33315
# 14250
# 13022
# 30403
# 10310
# 13130
# 28059
# 50302
# 37347
# 13022
# 34270
# 15113
# 33553
# 78100
# 21012
# 10813
# 37347
# 98870
# 72200
# 53220
# 33315
# 33315
# 52152
# 13022
# 16450
# 82300
# 33315
# 38300
# 48700
# 97064
# 76111
# 78492
# 50905
# 33517
# 13022
# 13022
# 04390
# 28059
# 70503
# 70503
# 10969
# 25350
# 10310
# 50470
# 72200
# 34045
# 76873
# 00848
# 50470
# 75654
# 98800
# 62700
# 47748
# 30512
# 70503
# 60603
# 33315
# 37347
# 10310
# 33315
# 30601
# 80047
# 32350
# 35460
# 50470
# 71000
# 33553
# 32350
# 83200
# 04400
# 34235
# 15113
# 50701
# 66289
# 12099
# 10969
# 31103
# 25167
# 72200
# 22203
# 37565
# 81630
# 22203
# 25167
# 78201
# 51449
# 20503
# 11701
# 50701
# 50504
# 50401
# 40206
# 10310
# 40206
# 71000
# 75570
# 25800
# 51449
# 78201
# 77515
# 70200
# 33475
# 84320
# 30403
# 50401
# 31516
# 35105
# 20278
# 81000
# 80303
# 72500
# 59700
# 23502
# 53700
# 76873
# 45502
# 04390
# 72200
# 71000
# 33315
# 81250
# 84320
# 81250
# 21012
# 70503
# 50701
# 71065
# 10408
# 10310
# 25167
# 48600
# 78492
# 33553
# 76111
# 72200
# 56600
# 73000
# 20240
# 06023
# 40000
# 32276
# 32011
# 70205
# 60200
# 10310
# 38174
# 51157
# 33315
# 80303
# 16520
# 10310
# 59700
# 76873
# 34270
# 78164
# 78332
# 76873
# 59700
