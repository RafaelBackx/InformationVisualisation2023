# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_events = pd.read_csv('../Natural-Disasters.csv',delimiter=';')
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_11692\3814874952.py:1: DtypeWarning: Columns (18,19,24,25,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_events = pd.read_csv('../Natural-Disasters.csv',delimiter=';')

# %%
df_events.describe()
# Out:
#                Year           Seq  AID Contribution ('000 US$)  Dis Mag Value  \
# count  16545.000000  16545.000000                 7.760000e+02   5.046000e+03
# mean    1997.700030    726.939015                 2.003959e+04   4.684230e+04
# std       20.323467   1943.470284                 1.690305e+05   3.076485e+05
# min     1900.000000      1.000000                 1.000000e+00  -5.700000e+01
# 25%     1990.000000     95.000000                 1.747500e+02   7.000000e+00
# 50%     2002.000000    276.000000                 7.245000e+02   1.500000e+02
# 75%     2012.000000    496.000000                 3.669750e+03   1.047575e+04
# max     2023.000000   9881.000000                 3.518530e+06   1.302587e+07
#
#          Start Year   Start Month     Start Day      End Year     End Month  \
# count  16545.000000  16150.000000  12936.000000  16545.000000  15845.000000
# mean    1997.708976      6.459071     15.227118   1997.763554      6.598233
# std       20.322089      3.398579      8.941742     20.310223      3.365517
# min     1900.000000      1.000000      1.000000   1900.000000      1.000000
# 25%     1990.000000      4.000000      7.000000   1990.000000      4.000000
# 50%     2002.000000      7.000000     15.000000   2002.000000      7.000000
# 75%     2012.000000      9.000000     23.000000   2012.000000      9.000000
# max     2023.000000     12.000000     31.000000   2023.000000     12.000000
#
#             End Day  ...    No Injured   No Affected   No Homeless  \
# count  13016.000000  ...  4.107000e+03  9.604000e+03  2.463000e+03
# mean      15.804471  ...  2.535969e+03  8.730170e+05  7.239043e+04
# std        8.873228  ...  3.353757e+04  8.422488e+06  5.195502e+05
# min        1.000000  ...  1.000000e+00  1.000000e+00  3.000000e+00
# 25%        8.000000  ...  1.300000e+01  1.249250e+03  5.555000e+02
# 50%       16.000000  ...  5.000000e+01  1.000000e+04  3.000000e+03
# 75%       24.000000  ...  2.000000e+02  9.171000e+04  1.727050e+04
# max       31.000000  ...  1.800000e+06  3.300000e+08  1.585000e+07
#
#        Total Affected  Reconstruction Costs ('000 US$)  \
# count    1.206000e+04                     3.400000e+01
# mean     7.108763e+05                     2.543790e+06
# std      7.594767e+06                     5.169353e+06
# min      1.000000e+00                     8.400000e+01
# 25%      6.595000e+02                     2.612500e+04
# 50%      6.000000e+03                     1.970000e+05
# 75%      5.892200e+04                     1.883547e+06
# max      3.300000e+08                     2.500000e+07
#
#        Reconstruction Costs, Adjusted ('000 US$)  Insured Damages ('000 US$)  \
# count                               3.400000e+01                1.109000e+03
# mean                                3.700856e+06                9.096904e+05
# std                                 8.415120e+06                3.711396e+06
# min                                 1.260000e+02                3.400000e+01
# 25%                                 4.287300e+04                5.000000e+04
# 50%                                 2.658890e+05                1.650000e+05
# 75%                                 2.085684e+06                5.000000e+05
# max                                 4.392238e+07                6.000000e+07
#
#        Insured Damages, Adjusted ('000 US$)  Total Damages ('000 US$)  \
# count                          1.109000e+03              5.367000e+03
# mean                           1.248945e+06              7.806739e+05
# std                            4.750374e+06              4.988408e+06
# min                            4.600000e+01              2.000000e+00
# 25%                            9.145200e+04              9.970000e+03
# 50%                            2.549260e+05              6.250000e+04
# 75%                            8.050520e+05              3.487500e+05
# max                            8.991316e+07              2.100000e+08
#
#        Total Damages, Adjusted ('000 US$)
# count                        5.365000e+03
# mean                         1.248384e+06
# std                          6.982026e+06
# min                          2.000000e+00
# 25%                          1.813900e+04
# 50%                          1.270310e+05
# 75%                          6.257570e+05
# max                          2.732184e+08
#
# [8 rows x 21 columns]

# %% [markdown]
# # Notes on the data
#
# Some things to take away from this dataset, first of all we have some missing start day and start month (the start years seem to be all there)
# sticking to the dates, most of the events seem to have occured in the late 90's and the 2000's

# %%
grouped_by_year = df_events.groupby('Start Year', as_index=False).sum()
fig = plt.figure(figsize=(15,8))
ax1 = fig.add_subplot(2,3,1)
ax1.set_title("Reconstruction costs per year")
ax1.bar(grouped_by_year['Start Year'], grouped_by_year['Reconstruction Costs (\'000 US$)'])
ax2 = fig.add_subplot(2,3,2)
ax2.set_title("adjusted, Reconstruction costs per year")
ax2.bar(grouped_by_year['Start Year'], grouped_by_year['Reconstruction Costs, Adjusted (\'000 US$)'])
ax3 = fig.add_subplot(2,3,4)
ax3.set_title('Nr affected by year')
ax3.bar(grouped_by_year['Start Year'], grouped_by_year['No Affected'])
ax4 = fig.add_subplot(2,3,5)
ax4.set_title('Nr homeless by year')
ax4.bar(grouped_by_year['Start Year'], grouped_by_year['No Homeless'])
ax5 = fig.add_subplot(2,3,6)
ax5.set_title("Nr injured by year")
ax5.bar(grouped_by_year['Start Year'], grouped_by_year['No Injured'])
plt.show()
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_11692\4044557679.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_by_year = df_events.groupby('Start Year', as_index=False).sum()

# %% [markdown]
# There also seems to be no data for the reconstruction costs between the 1900 - (late) 1990,
# Number of affected, homeless and injured is also mostly from 1960-2023
#
# We may need to look to augment these columns with extra data found, there is a uuid field (glide) which should be able to specificaly identify each natural disaster so maybe we can use this to augment these columns ?

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Aid by year")
ax.bar(grouped_by_year['Start Year'], grouped_by_year['AID Contribution (\'000 US$)'])
# Out:
# <BarContainer object of 124 artists>

# %% [markdown]
# The aid field (which might not be all that interesting for our visualisations anyway) is also really underpopulated

# %%
df_events[~df_events['Admin1 Code'].isna()]['Admin1 Code'].head()
# Out:
# 5735                                                61515
# 6401            40546;40548;40549;40552;40554;40557;40558
# 6450                                                  914
# 6451    272;273;274;277;279;281;282;285;287;289;293;29...
# 6453                  40444;40445;40446;40447;40448;40450
# Name: Admin1 Code, dtype: object

# %% [markdown]
# Other underpopulated columns are Latitude and Longitude, these are necessary. They will have to be augmented.

# %%
df_events[df_events["Latitude"].isna() | df_events["Longitude"].isna()].groupby("Year").count()["Dis No"].plot.bar()
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# I propose we drop the following columns:
#
# 1. Year (unclear imo, we already have start year and end year)
# 2. Glide (for now, from the documentation we can conclude that is a uuid for natural disasters, so if we find another dataset to augment this one we can still use it to link events with each other)
# 3. Location (again I don't think we need it since we already have Country, ISO, Latitude and Longitude)
# 4. OFDA Response (I don't think this is usefull for our visualisations)
# 5. Appeal (Again not sure if this is relevant for our visualisations)
# 6. Declaration (related to Appeal, not really relevant imo)
# 8. Adm Level, Admin1 Code, Admin2 Code (I don't think they are explained in the accompanying documentation and I can't figure them out so not usefull imo)
# 9. Geo Locations (they seem to be related with Admin1 code and Admin2 code, and I think we have enough location data for now)
# 10. Seq
# 11. Disaster Group
# 12. Diaster Subgroup
#     - Extra Terrestial
#     - Biological ?

# %%
df_events[~df_events['Reconstruction Costs (\'000 US$)'].isna()]
# Out:
#               Dis No  Year  Seq           Glide Disaster Group  \
# 3905   1991-0249-CHL  1991  249             NaN        Natural
# 5251   1997-0200-BLR  1997  200             NaN        Natural
# 5471   1995-0211-DMA  1995  211             NaN        Natural
# 5581   1996-0052-MOZ  1996   52             NaN        Natural
# 6677   1999-0611-FRA  1999  611             NaN        Natural
# 6726   1999-0235-IRN  1999  235             NaN        Natural
# 7112   1999-0449-TUR  1999  449             NaN        Natural
# 7208   1999-0268-TUR  1999  268             NaN        Natural
# 7224   1999-0298-USA  1999  298             NaN        Natural
# 7515   2002-0110-BOL  2002  110             NaN        Natural
# 9410   2005-0451-CHE  2005  451             NaN        Natural
# 9823   2005-0575-PAK  2005  575             NaN        Natural
# 9848   2005-0448-SEN  2005  448             NaN        Natural
# 10129  2006-0181-ZAF  2006  181             NaN        Natural
# 10260  2007-0305-BFA  2007  305  FL-2007-000132        Natural
# 10369  2008-0549-BRA  2008  549             NaN        Natural
# 10668  2007-0557-PNG  2007  557  FL-2007-000209        Natural
# 11359  2010-0260-GTM  2010  260             NaN        Natural
# 11368  2010-0017-HTI  2010   17  EQ-2010-000009        Natural
# 11611  2010-0068-PRT  2010   68             NaN        Natural
# 12191  2013-0077-BRA  2013   77             NaN        Natural
# 13142  2016-0117-ECU  2016  117  EQ-2016-000035        Natural
# 13852  2017-0271-CAN  2017  271             NaN        Natural
# 13879  2017-0381-ATG  2017  381  TC-2017-000132        Natural
# 14210  2017-0176-PRT  2017  176             NaN        Natural
# 14298  2017-0205-KEN  2017  205             NaN        Natural
# 14328  2017-0272-NGA  2017  272             NaN        Natural
# 14337  2017-0247-PHL  2017  247             NaN        Natural
# 14355  2018-0352-IDN  2018  352  EQ-2018-000122        Natural
# 14750  2017-0205-TZA  2017  205             NaN        Natural
# 15090  2021-0790-BRA  2021  790  FL-2021-000204        Natural
# 15427  2020-0106-HRV  2020  106  EQ-2020-000040        Natural
# 15629  2021-0511-HTI  2021  511  EQ-2021-000116        Natural
# 16351  2022-0405-PAK  2022  405  FL-2022-000270        Natural
#
#       Disaster Subgroup Disaster Type      Disaster Subtype  \
# 3905       Hydrological     Landslide              Mudslide
# 5251     Meteorological         Storm      Tropical cyclone
# 5471     Meteorological         Storm      Tropical cyclone
# 5581     Meteorological         Storm      Tropical cyclone
# 6677     Meteorological         Storm  Extra-tropical storm
# 6726       Hydrological         Flood           Flash flood
# 7112        Geophysical    Earthquake       Ground movement
# 7208        Geophysical    Earthquake       Ground movement
# 7224     Meteorological         Storm      Tropical cyclone
# 7515       Hydrological         Flood        Riverine flood
# 9410       Hydrological         Flood        Riverine flood
# 9823        Geophysical    Earthquake       Ground movement
# 9848       Hydrological         Flood        Riverine flood
# 10129      Hydrological         Flood        Riverine flood
# 10260      Hydrological         Flood        Riverine flood
# 10369      Hydrological         Flood        Riverine flood
# 10668    Meteorological         Storm      Tropical cyclone
# 11359    Meteorological         Storm      Tropical cyclone
# 11368       Geophysical    Earthquake       Ground movement
# 11611      Hydrological         Flood        Riverine flood
# 12191      Hydrological         Flood        Riverine flood
# 13142       Geophysical    Earthquake       Ground movement
# 13852    Climatological      Wildfire                   NaN
# 13879    Meteorological         Storm      Tropical cyclone
# 14210    Climatological      Wildfire           Forest fire
# 14298      Hydrological         Flood        Riverine flood
# 14328      Hydrological         Flood                   NaN
# 14337       Geophysical    Earthquake       Ground movement
# 14355       Geophysical    Earthquake               Tsunami
# 14750      Hydrological         Flood        Riverine flood
# 15090      Hydrological         Flood                   NaN
# 15427       Geophysical    Earthquake       Ground movement
# 15629       Geophysical    Earthquake       Ground movement
# 16351      Hydrological         Flood                   NaN
#
#       Disaster Subsubtype                                Event Name  ...  \
# 3905                  NaN                                       NaN  ...
# 5251                  NaN                                       NaN  ...
# 5471                  NaN                                      Luis  ...
# 5581                  NaN                                    Bonita  ...
# 6677                  NaN                                    Martin  ...
# 6726                  NaN                                       NaN  ...
# 7112                  NaN                                       NaN  ...
# 7208                  NaN                                       NaN  ...
# 7224                  NaN                                      Bret  ...
# 7515                  NaN                                       NaN  ...
# 9410                  NaN                                       NaN  ...
# 9823                  NaN                                       NaN  ...
# 9848                  NaN                                       NaN  ...
# 10129                 NaN                                       NaN  ...
# 10260                 NaN                                       NaN  ...
# 10369                 NaN                                       NaN  ...
# 10668                 NaN                            Cyclone 'Guba'  ...
# 11359                 NaN                     Tropical storm "Alex"  ...
# 11368                 NaN                                       NaN  ...
# 11611                 NaN                                       NaN  ...
# 12191                 NaN                                       NaN  ...
# 13142                 NaN                                       NaN  ...
# 13852                 NaN  Gustafsen, Wildwood, Elephant Hill Fires  ...
# 13879                 NaN                          Hurricane 'Irma'  ...
# 14210                 NaN                                       NaN  ...
# 14298                 NaN                                       NaN  ...
# 14328                 NaN                                       NaN  ...
# 14337                 NaN                                       NaN  ...
# 14355                 NaN                                       NaN  ...
# 14750                 NaN                                       NaN  ...
# 15090                 NaN                                       NaN  ...
# 15427                 NaN                                       NaN  ...
# 15629                 NaN                                       NaN  ...
# 16351                 NaN                                       NaN  ...
#
#       Reconstruction Costs, Adjusted ('000 US$) Insured Damages ('000 US$)  \
# 3905                                     6447.0                        NaN
# 5251                                   273481.0                        NaN
# 5471                                   124834.0                        NaN
# 5581                                    26122.0                        NaN
# 6677                                  4304394.0                        NaN
# 6726                                     5271.0                        NaN
# 7112                                 17568953.0                        NaN
# 7208                                 43922383.0                  2000000.0
# 7224                                   109806.0                        NaN
# 7515                                    16270.0                        NaN
# 9410                                  1191349.0                  1525000.0
# 9823                                  7792473.0                        NaN
# 9848                                      126.0                        NaN
# 10129                                  185164.0                        NaN
# 10260                                    8469.0                        NaN
# 10369                                  731289.0                   470000.0
# 10668                                  258297.0                        NaN
# 11359                                 1308559.0                        NaN
# 11368                                15434285.0                   200000.0
# 11611                                 1933649.0                    70000.0
# 12191                                    1897.0                        NaN
# 13142                                 4077535.0                   560000.0
# 13852                                   93126.0                        NaN
# 13879                                  238785.0                     6800.0
# 14210                                  674568.0                    19000.0
# 14298                                  231622.0                        NaN
# 14328                                    6089.0                        NaN
# 14337                                    6328.0                        NaN
# 14355                                 1864736.0                        NaN
# 14750                                  231622.0                        NaN
# 15090                                  379090.0                        NaN
# 15427                                10685737.0                        NaN
# 15629                                 2136363.0                        NaN
# 16351                                10000000.0                     7000.0
#
#       Insured Damages, Adjusted ('000 US$) Total Damages ('000 US$)  \
# 3905                                   NaN                   6000.0
# 5251                                   NaN                  33000.0
# 5471                                   NaN                  20000.0
# 5581                                   NaN                  14500.0
# 6677                                   NaN                4000000.0
# 6726                                   NaN                  43000.0
# 7112                                   NaN                1000000.0
# 7208                             3513791.0               20000000.0
# 7224                                   NaN                  70000.0
# 7515                                   NaN                 100000.0
# 9410                             2285293.0                2100000.0
# 9823                                   NaN                5200000.0
# 9848                                   NaN                      NaN
# 10129                                  NaN                  71000.0
# 10260                                  NaN                      NaN
# 10369                             638858.0                 750000.0
# 10668                                  NaN                      NaN
# 11359                                  NaN                      NaN
# 11368                             268422.0                8000000.0
# 11611                              93948.0                1350000.0
# 12191                                  NaN                   1500.0
# 13142                             682841.0                2000000.0
# 13852                                  NaN                      NaN
# 13879                               8119.0                 250000.0
# 14210                              22685.0                 232000.0
# 14298                                  NaN                      NaN
# 14328                                  NaN                      NaN
# 14337                                  NaN                   4364.0
# 14355                                  NaN                1450000.0
# 14750                                  NaN                      NaN
# 15090                                  NaN                 417000.0
# 15427                                  NaN                6800000.0
# 15629                                  NaN                1620071.0
# 16351                               7000.0               15000000.0
#
#       Total Damages, Adjusted ('000 US$)          CPI Adm Level  \
# 3905                             12893.0  46,53662061       NaN
# 5251                             60166.0  54,84845417       NaN
# 5471                             38410.0  52,06929869       NaN
# 5581                             27054.0  53,59556085       NaN
# 6677                           7027581.0  56,91858704       NaN
# 6726                             75546.0  56,91858704       NaN
# 7112                           1756895.0  56,91858704       NaN
# 7208                          35137907.0  56,91858704       NaN
# 7224                            122983.0  56,91858704       NaN
# 7515                            162699.0  61,46318826         2
# 9410                           3146960.0  66,73105799         1
# 9823                           7792473.0  66,73105799         2
# 9848                                 NaN  66,73105799         2
# 10129                           103072.0  68,88375871         2
# 10260                                NaN   70,8487927       1;2
# 10369                          1019455.0  73,56874554         2
# 10668                                NaN   70,8487927       1;2
# 11359                                NaN  74,50944408       1;2
# 11368                         10736894.0  74,50944408         2
# 11611                          1811851.0  74,50944408         2
# 12191                             1884.0  79,60130942         2
# 13142                          2438717.0   82,0103309       1;2
# 13852                                NaN  83,75725455         2
# 13879                           298482.0  83,75725455         1
# 14210                           276991.0  83,75725455         2
# 14298                                NaN  83,75725455         1
# 14328                                NaN  83,75725455         1
# 14337                             5210.0  83,75725455         2
# 14355                          1689917.0  85,80302606         2
# 14750                                NaN  83,75725455         1
# 15090                           450372.0  92,59019293       1;2
# 15427                          7689208.0  88,43564081         1
# 15629                          1749722.0  92,59019293         1
# 16351                         15000000.0          100       1;2
#
#                                              Admin1 Code  \
# 3905                                                 NaN
# 5251                                                 NaN
# 5471                                                 NaN
# 5581                                                 NaN
# 6677                                                 NaN
# 6726                                                 NaN
# 7112                                                 NaN
# 7208                                                 NaN
# 7224                                                 NaN
# 7515                                                 NaN
# 9410                            2812;2818;2821;2824;2828
# 9823                                                 NaN
# 9848                                                 NaN
# 10129                                                NaN
# 10260                                              40287
# 10369                                                NaN
# 10668                                               2303
# 11359                                  64830;64832;64842
# 11368                                                NaN
# 11611                                                NaN
# 12191                                                NaN
# 13142                                   1147;22007;22008
# 13852                                                NaN
# 13879                                  40206;40208;40209
# 14210                                                NaN
# 14298                            51325;51326;51329;51332
# 14328  2212;2219;2227;2229;2230;2231;2234;2235;65698;...
# 14337                                                NaN
# 14355                                                NaN
# 14750                                              48381
# 15090                                        672;677;691
# 15427                                           990;1008
# 15629                                   1416;72911;72912
# 16351                                    2276;2277;40408
#
#                                              Admin2 Code  \
# 3905                                                 NaN
# 5251                                                 NaN
# 5471                                                 NaN
# 5581                                                 NaN
# 6677                                                 NaN
# 6726                                                 NaN
# 7112                                                 NaN
# 7208                                                 NaN
# 7224                                                 NaN
# 7515                                                6185
# 9410                                                 NaN
# 9823   23638;23674;40329;40331;40340;40344;40348;4036...
# 9848                                          1382;25321
# 10129                                              77348
# 10260  154450;154453;154454;154455;154456;154462;1544...
# 10369  10720;10722;10780;10781;10795;10814;10819;1083...
# 10668                                              37518
# 11359                                              64930
# 11368          17168;17177;17194;17197;17198;17201;17203
# 11611                                              24789
# 12191                           9895;9919;9934;9941;9948
# 13142                                  15388;15423;15483
# 13852                                        12542;12566
# 13879                                                NaN
# 14210                24727;24732;24738;24814;24815;24820
# 14298                                                NaN
# 14328                                                NaN
# 14337                                              24258
# 14355                      73671;73741;73785;73821;73830
# 14750                                                NaN
# 15090       6658;6706;6712;6716;6749;6784;6840;6842;6917
# 15427                                                NaN
# 15629                                                NaN
# 16351          23622;23632;40296;40297;40300;40302;40310
#
#                                            Geo Locations
# 3905                                                 NaN
# 5251                                                 NaN
# 5471                                                 NaN
# 5581                                                 NaN
# 6677                                                 NaN
# 6726                                                 NaN
# 7112                                                 NaN
# 7208                                                 NaN
# 7224                                                 NaN
# 7515                                     Murillo (Adm2).
# 9410         Bern, Luzern, Obwalden, Schwyz, Uri (Adm1).
# 9823   Abbottabad District, Batagram District, Gujran...
# 9848                             Dakar, Rufisque (Adm2).
# 10129  Dr Ruth Segomotsi Mompati District Municipalit...
# 10260  Sahel (Adm1). Bam, Houet, Kadiogo, Kouritenga,...
# 10369  Benedito Novo, Blumenau, Garuva, Gaspar, Ilhot...
# 10668                  Northern (Adm1). Rabaraba (Adm2).
# 11359  Jutiapa, San Marcos, Suchitepéquez (Adm1). San...
# 11368  Cayes, Croix-Des-Bouquets, Gonaives, Jacmel, J...
# 11611                                    Funchal (Adm2).
# 12191  Angra Dos Reis, Duque De Caxias, Mangaratiba, ...
# 13142  Los Rios, Santa Elena, Santo Domingo de los Ts...
# 13852                   Cariboo, Thompson-Nicola (Adm2).
# 13879              Barbuda, St. George, St. John (Adm1).
# 14210  Arganil, Castanheira De Pera, Figueiro Dos Vin...
# 14298     Central, Coast, North Eastern, Western (Adm1).
# 14328  Abia, Akwa Ibom, Bayelsa, Ebonyi, Edo, Ekiti, ...
# 14337                                      Leyte (Adm2).
# 14355  Donggala, Kota Palu, Mamuju Utara, Parigimouto...
# 14750                                      Tanga (Adm1).
# 15090  Espirito Santo, Minas Gerais, Tocantins (Adm1)...
# 15427                        Grad Zagreb, Zagreb (Adm1).
# 15629                   Grande Anse, Nippes, Sud (Adm1).
# 16351  Jammu and Kashmir (Administrative unit not ava...
#
# [34 rows x 50 columns]

# %%
df_events[~df_events['Total Damages, Adjusted (\'000 US$)'].isna()]
# Out:
#               Dis No  Year  Seq Glide Disaster Group Disaster Subgroup  \
# 2      1902-0012-GTM  1902   12   NaN        Natural       Geophysical
# 9      1905-0003-IND  1905    3   NaN        Natural       Geophysical
# 10     1906-0014-CHL  1906   14   NaN        Natural       Geophysical
# 14     1906-0015-HKG  1906   15   NaN        Natural    Meteorological
# 35     1912-0021-CAN  1912   21   NaN        Natural    Meteorological
# ...              ...   ...  ...   ...            ...               ...
# 16514  2022-0808-USA  2022  808   NaN        Natural       Geophysical
# 16515  2022-0811-USA  2022  811   NaN        Natural    Meteorological
# 16516  2022-0734-USA  2022  734   NaN        Natural    Meteorological
# 16517  2022-0215-USA  2022  215   NaN        Natural    Climatological
# 16520  2022-0480-USA  2022  480   NaN        Natural      Hydrological
#
#       Disaster Type  Disaster Subtype Disaster Subsubtype  \
# 2        Earthquake   Ground movement                 NaN
# 9        Earthquake   Ground movement                 NaN
# 10       Earthquake   Ground movement                 NaN
# 14            Storm  Tropical cyclone                 NaN
# 35            Storm  Convective storm             Tornado
# ...             ...               ...                 ...
# 16514    Earthquake   Ground movement                 NaN
# 16515         Storm  Convective storm                 NaN
# 16516         Storm  Tropical cyclone                 NaN
# 16517      Wildfire               NaN                 NaN
# 16520         Flood               NaN                 NaN
#
#                                       Event Name  ...  \
# 2                                            NaN  ...
# 9                                            NaN  ...
# 10                                           NaN  ...
# 14                                           NaN  ...
# 35                                           NaN  ...
# ...                                          ...  ...
# 16514                                        NaN  ...
# 16515                                        NaN  ...
# 16516                         Hurricane 'Nicole'  ...
# 16517  McBride, Nogal Canyon, Hermits Peak Fires  ...
# 16520                                        NaN  ...
#
#       Reconstruction Costs, Adjusted ('000 US$) Insured Damages ('000 US$)  \
# 2                                           NaN                        NaN
# 9                                           NaN                        NaN
# 10                                          NaN                        NaN
# 14                                          NaN                        NaN
# 35                                          NaN                        NaN
# ...                                         ...                        ...
# 16514                                       NaN                        NaN
# 16515                                       NaN                        NaN
# 16516                                       NaN                        NaN
# 16517                                       NaN                        NaN
# 16520                                       NaN                        NaN
#
#       Insured Damages, Adjusted ('000 US$) Total Damages ('000 US$)  \
# 2                                      NaN                  25000.0
# 9                                      NaN                  25000.0
# 10                                     NaN                 100000.0
# 14                                     NaN                  20000.0
# 35                                     NaN                   5000.0
# ...                                    ...                      ...
# 16514                                  NaN                 250000.0
# 16515                                  NaN                 345000.0
# 16516                                  NaN                1000000.0
# 16517                                  NaN                 155000.0
# 16520                                  NaN                1500000.0
#
#       Total Damages, Adjusted ('000 US$)          CPI Adm Level  \
# 2                               843726.0  2,963047785       NaN
# 9                               812477.0  3,077011162       NaN
# 10                             3249907.0  3,077011162       NaN
# 14                              649981.0  3,077011162       NaN
# 35                              151289.0  3,304937914       NaN
# ...                                  ...          ...       ...
# 16514                           250000.0        100.0         2
# 16515                           345000.0        100.0         1
# 16516                          1000000.0        100.0       NaN
# 16517                           155000.0        100.0         2
# 16520                          1500000.0        100.0         1
#
#                               Admin1 Code        Admin2 Code  \
# 2                                     NaN                NaN
# 9                                     NaN                NaN
# 10                                    NaN                NaN
# 14                                    NaN                NaN
# 35                                    NaN                NaN
# ...                                   ...                ...
# 16514                                 NaN              28876
# 16515  3214;3223;3224;3232;3238;3250;3257                NaN
# 16516                                 NaN                NaN
# 16517                                 NaN  28787;30486;30496
# 16520                           3231;3239                NaN
#
#                                            Geo Locations
# 2                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 14                                                   NaN
# 35                                                   NaN
# ...                                                  ...
# 16514                                   Humboldt (Adm2).
# 16515  Alabama, Florida, Georgia, Louisiana, Mississi...
# 16516                                                NaN
# 16517            Lincoln, San Miguel, Santa Cruz (Adm2).
# 16520                         Kentucky, Missouri (Adm1).
#
# [5365 rows x 50 columns]
